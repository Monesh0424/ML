# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_data():
    return pd.read_csv(r"C:\Users\USER\Desktop\Machine learning\chapter - 2  End - End project\datasets\life expectancy\datasets_12603_17232_Life Expectancy Data.csv")

# %%
life = load_data()
life.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
life[life['Country']=='India']['Year']
# Out:
# 1186    2015
# 1187    2014
# 1188    2013
# 1189    2012
# 1190    2011
# 1191    2010
# 1192    2009
# 1193    2008
# 1194    2007
# 1195    2006
# 1196    2005
# 1197    2004
# 1198    2003
# 1199    2002
# 1200    2001
# 1201    2000
# Name: Year, dtype: int64

# %%
life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
life.drop('Status',axis=1,inplace=True)
life.head()
# Out:
#        Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# 0  Afghanistan  2015              65.0            263.0             62
# 1  Afghanistan  2014              59.9            271.0             64
# 2  Afghanistan  2013              59.9            268.0             66
# 3  Afghanistan  2012              59.5            272.0             69
# 4  Afghanistan  2011              59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   ...  Polio  \
# 0     0.01               71.279624         65.0      1154   19.1  ...    6.0
# 1     0.01               73.523582         62.0       492   18.6  ...   58.0
# 2     0.01               73.219243         64.0       430   18.1  ...   62.0
# 3     0.01               78.184215         67.0      2787   17.6  ...   67.0
# 4     0.01                7.097109         68.0      3013   17.2  ...   68.0
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
life.drop('Year',axis=1,inplace=True)
life.head()
# Out:
#        Country  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan              65.0            263.0             62     0.01
# 1  Afghanistan              59.9            271.0             64     0.01
# 2  Afghanistan              59.9            268.0             66     0.01
# 3  Afghanistan              59.5            272.0             69     0.01
# 4  Afghanistan              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
# ...

# %%
df = life.groupby(by='Country').mean()

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                Country  Life expectancy   Adult Mortality  infant deaths  \
# 0          Afghanistan          58.19375         269.0625        78.2500
# 1              Albania          75.15625          45.0625         0.6875
# 2              Algeria          73.61875         108.1875        20.3125
# 3               Angola          49.01875         328.5625        83.7500
# 4  Antigua and Barbuda          75.05625         127.5000         0.0000
#
#     Alcohol  percentage expenditure  Hepatitis B   Measles       BMI   \
# 0  0.014375               34.960110    64.562500  2362.2500  15.51875
# 1  4.848750              193.259091    98.000000    53.3750  49.06875
# 2  0.406667              236.185241    78.000000  1943.8750  48.74375
# 3  5.740667              102.100268    70.222222  3561.3125  18.01875
# 4  7.949333             1001.585226    98.266667     0.0000  38.42500
#
#    under-five deaths     Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# ...

# %%
df[df['Country'] == 'India']
# Out:
#    Country  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 76   India          65.41875         146.5625      1366.6875    1.942
#
#     percentage expenditure  Hepatitis B    Measles       BMI   \
# 76               33.242621         35.0  46454.1875  14.79375
#
#     under-five deaths    Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 76              1812.5  69.625           4.358667      67.0625    0.25625
#
#            GDP    Population   thinness  1-19 years   thinness 5-9 years  \
# 76  837.920051  4.214677e+08                   27.1             27.94375
#
#     Income composition of resources  Schooling
# 76                           0.5495    9.98125

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          193 non-null    object
#  1   Life expectancy                  183 non-null    float64
#  2   Adult Mortality                  183 non-null    float64
#  3   infant deaths                    193 non-null    float64
#  4   Alcohol                          191 non-null    float64
#  5   percentage expenditure           193 non-null    float64
#  6   Hepatitis B                      184 non-null    float64
#  7   Measles                          193 non-null    float64
#  8    BMI                             189 non-null    float64
#  9   under-five deaths                193 non-null    float64
#  10  Polio                            193 non-null    float64
# ...

# %%
df2 = list(df.columns)

# %%
df2
# Out:
# ['Country',
#  'Life expectancy ',
#  'Adult Mortality',
#  'infant deaths',
#  'Alcohol',
#  'percentage expenditure',
#  'Hepatitis B',
#  'Measles ',
#  ' BMI ',
#  'under-five deaths ',
#  'Polio',
#  'Total expenditure',
#  'Diphtheria ',
#  ' HIV/AIDS',
#  'GDP',
#  'Population',
#  ' thinness  1-19 years',
#  ' thinness 5-9 years',
#  'Income composition of resources',
#  'Schooling']

# %%
df
# Out:
#                                 Country  Life expectancy   Adult Mortality  \
# 0                           Afghanistan          58.19375         269.0625
# 1                               Albania          75.15625          45.0625
# 2                               Algeria          73.61875         108.1875
# 3                                Angola          49.01875         328.5625
# 4                   Antigua and Barbuda          75.05625         127.5000
# ..                                  ...               ...              ...
# 188  Venezuela (Bolivarian Republic of)          73.38750         163.0000
# 189                            Viet Nam          74.77500         126.5625
# 190                               Yemen          63.86250         211.8125
# 191                              Zambia          53.90625         354.3125
# 192                            Zimbabwe          50.48750         462.3750
#
# ...

# %%
df.drop(' thinness 5-9 years',inplace=True,axis=1)

# %%
df.head()
# Out:
#                Country  Life expectancy   Adult Mortality  infant deaths  \
# 0          Afghanistan          58.19375         269.0625        78.2500
# 1              Albania          75.15625          45.0625         0.6875
# 2              Algeria          73.61875         108.1875        20.3125
# 3               Angola          49.01875         328.5625        83.7500
# 4  Antigua and Barbuda          75.05625         127.5000         0.0000
#
#     Alcohol  percentage expenditure  Hepatitis B   Measles       BMI   \
# 0  0.014375               34.960110    64.562500  2362.2500  15.51875
# 1  4.848750              193.259091    98.000000    53.3750  49.06875
# 2  0.406667              236.185241    78.000000  1943.8750  48.74375
# 3  5.740667              102.100268    70.222222  3561.3125  18.01875
# 4  7.949333             1001.585226    98.266667     0.0000  38.42500
#
#    under-five deaths     Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# ...

# %%
df.head()
# Out:
#                Country  Life expectancy   Adult Mortality  infant deaths  \
# 0          Afghanistan          58.19375         269.0625        78.2500
# 1              Albania          75.15625          45.0625         0.6875
# 2              Algeria          73.61875         108.1875        20.3125
# 3               Angola          49.01875         328.5625        83.7500
# 4  Antigua and Barbuda          75.05625         127.5000         0.0000
#
#     Alcohol  percentage expenditure  Hepatitis B   Measles       BMI   \
# 0  0.014375               34.960110    64.562500  2362.2500  15.51875
# 1  4.848750              193.259091    98.000000    53.3750  49.06875
# 2  0.406667              236.185241    78.000000  1943.8750  48.74375
# 3  5.740667              102.100268    70.222222  3561.3125  18.01875
# 4  7.949333             1001.585226    98.266667     0.0000  38.42500
#
#    under-five deaths     Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# ...

# %%
df.describe()
# Out:
#        Life expectancy   Adult Mortality  infant deaths     Alcohol  \
# count        183.000000       183.000000     193.000000  191.000000
# mean          69.224932       164.796448      28.831930    4.439915
# std            9.186432        96.185159     113.136586    3.879682
# min           46.112500        18.750000       0.000000    0.010000
# 25%           62.475000        80.406250       0.000000    0.969667
# 50%           72.487500       146.562500       2.562500    3.505333
# 75%           75.106250       219.593750      20.750000    7.443000
# max           82.537500       550.062500    1366.687500   13.497333
#
#        percentage expenditure  Hepatitis B      Measles         BMI   \
# count              193.000000   184.000000    193.000000  189.000000
# mean               708.811674    78.518282   2302.060233   39.554530
# std               1449.445611    18.821051   7886.208390   17.602749
# min                  0.000000     8.000000      0.000000    5.200000
# ...

# %% [markdown]
# # Histogram for dataset

# %%
df.hist(bins=50,figsize=(12,8))
plt.tight_layout()

# %%
df['Income composition of resources'] = df['Income composition of resources'].fillna(df['Income composition of resources'].mean())

# %%
df['Income composition of resources'].isna().sum()
# Out:
# 0

# %%
df['income_resources'] = pd.cut(df['Income composition of resources'],bins = [0.1,0.3,0.5,0.7,np.inf] , labels = [1,2,3,4])

# %%
df.head(1)
# Out:
#        Country  Life expectancy   Adult Mortality  infant deaths   Alcohol  \
# 0  Afghanistan          58.19375         269.0625          78.25  0.014375
#
#    percentage expenditure  Hepatitis B  Measles       BMI   \
# 0                34.96011      64.5625   2362.25  15.51875
#
#    under-five deaths    Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 0            107.5625  48.375             8.2525      52.3125        0.1
#
#           GDP    Population   thinness  1-19 years  \
# 0  340.015425  9.972260e+06               16.58125
#
#    Income composition of resources  Schooling income_resources
# 0                         0.415375     8.2125                2

# %%
df['income_resources'].hist()

# %%
df['income_resources'].value_counts()
# Out:
# 4    74
# 3    68
# 2    43
# 1     8
# Name: income_resources, dtype: int64

# %% [markdown]
# # Splitting data frame into training and testing datasets

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
split = StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)

# %%
for train,test in split.split(df , df['income_resources']):
    train_data = df.loc[train]
    test_data = df.loc[test]

# %%
len(train_data)
# Out:
# 154

# %%
len(test_data)
# Out:
# 39

# %%
for i in (train_data,test_data):
    i.drop("income_resources",axis=1,inplace=True)

# %%
train_data.head(1)
# Out:
#      Country  Life expectancy   Adult Mortality  infant deaths   Alcohol  \
# 123  Nigeria          51.35625            248.5       535.6875  8.646667
#
#      percentage expenditure  Hepatitis B    Measles    BMI   \
# 123               85.444275    42.909091  51653.9375  19.75
#
#      under-five deaths     Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 123            852.0625  41.3125           3.710667      39.3125    4.83125
#
#              GDP    Population   thinness  1-19 years  \
# 123  1360.139877  7.087700e+07               10.41875
#
#      Income composition of resources  Schooling
# 123                         0.367375        9.0

# %% [markdown]
# # Visualisation

# %%
train_data.corr()
# Out:
#                                  Life expectancy   Adult Mortality  \
# Life expectancy                          1.000000        -0.888738
# Adult Mortality                         -0.888738         1.000000
# infant deaths                           -0.200290         0.097230
# Alcohol                                  0.435755        -0.263451
# percentage expenditure                   0.483716        -0.391980
# Hepatitis B                              0.519373        -0.387743
# Measles                                 -0.271199         0.150250
#  BMI                                     0.740882        -0.631068
# under-five deaths                       -0.223973         0.114688
# Polio                                    0.706993        -0.549086
# Total expenditure                        0.296725        -0.187076
# Diphtheria                               0.701983        -0.523780
#  HIV/AIDS                               -0.578004         0.694804
# ...

# %%
train_data.hist(bins=50,figsize=(12,8))
plt.tight_layout()

# %%
corr = train_data.corr()
corr['Life expectancy '].sort_values(ascending=False)
# Out:
# Life expectancy                    1.000000
# Schooling                          0.799555
# Income composition of resources    0.767622
#  BMI                               0.740882
# Polio                              0.706993
# Diphtheria                         0.701983
# GDP                                0.592415
# Hepatitis B                        0.519373
# percentage expenditure             0.483716
# Alcohol                            0.435755
# Total expenditure                  0.296725
# Population                        -0.040018
# infant deaths                     -0.200290
# under-five deaths                 -0.223973
# Measles                           -0.271199
#  thinness  1-19 years             -0.481882
#  HIV/AIDS                         -0.578004
# Adult Mortality                   -0.888738
# Name: Life expectancy , dtype: float64

# %%
from pandas.plotting import scatter_matrix

# %%
attributes = ["Schooling","Income composition of resources"," BMI","Polio","Diphtheria"]

# %%
train_data.head()
# Out:
#                               Country  Life expectancy   Adult Mortality  \
# 123                           Nigeria          51.35625         248.5000
# 40                            Croatia          76.11875          89.0000
# 180                           Ukraine          69.93750         205.7500
# 144  Saint Vincent and the Grenadines          73.47500         152.0625
# 117                             Nauru               NaN              NaN
#
#      infant deaths    Alcohol  percentage expenditure  Hepatitis B  \
# 123       535.6875   8.646667               85.444275    42.909091
# 40          0.0000  12.448000             1162.856329    96.222222
# 180         5.0625   7.369333              169.427330    54.625000
# 144         0.0000   6.110000                0.000000    93.000000
# 117         0.0000   0.010000               15.606596    87.000000
#
#        Measles       BMI   under-five deaths     Polio  Total expenditure  \
# ...

# %%
for i in (train_data,test_data):
    i.drop("Country",inplace=True,axis=1)

# %%
train_data.head()
# Out:
#      Life expectancy   Adult Mortality  infant deaths    Alcohol  \
# 123          51.35625         248.5000       535.6875   8.646667
# 40           76.11875          89.0000         0.0000  12.448000
# 180          69.93750         205.7500         5.0625   7.369333
# 144          73.47500         152.0625         0.0000   6.110000
# 117               NaN              NaN         0.0000   0.010000
#
#      percentage expenditure  Hepatitis B    Measles       BMI   \
# 123               85.444275    42.909091  51653.9375  19.75000
# 40              1162.856329    96.222222     23.6875  52.35625
# 180              169.427330    54.625000   5395.1875  50.89375
# 144                0.000000    93.000000      0.0000  41.99375
# 117               15.606596    87.000000      0.0000  87.30000
#
#      under-five deaths     Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# 123            852.0625  41.3125           3.710667      39.3125    4.83125
# ...

# %%
train_data_features = train_data.drop('Life expectancy ',axis=1)
train_data_labels = train_data[['Life expectancy ']]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
from sklearn.base import BaseEstimator , TransformerMixin

# %% [raw]
# Column names for the data frame consists of spaces. Creating class to format the column names

# %%
class RemovingSpaces(BaseEstimator,TransformerMixin):
    def __init__(self,columns=True):
        self.columns = columns
        
    def fit(self,X,y=None):
        return self
    
    def transform(self,X,y=None):
        col = list(X.columns)
        li = []
        for i in col:
            li.append(i.strip())
        return pd.DataFrame(data=X.values,columns=li,index=X.index)

# %%
remove = RemovingSpaces()

# %%
train_data = remove.fit_transform(train_data)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 123 to 77
# Data columns (total 18 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Life expectancy                  145 non-null    float64
#  1   Adult Mortality                  145 non-null    float64
#  2   infant deaths                    154 non-null    float64
#  3   Alcohol                          153 non-null    float64
#  4   percentage expenditure           154 non-null    float64
#  5   Hepatitis B                      146 non-null    float64
#  6   Measles                          154 non-null    float64
#  7   BMI                              152 non-null    float64
#  8   under-five deaths                154 non-null    float64
#  9   Polio                            154 non-null    float64
#  10  Total expenditure                153 non-null    float64
# ...

# %%
train_data.head(2)
# Out:
#      Life expectancy  Adult Mortality  infant deaths    Alcohol  \
# 123         51.35625            248.5       535.6875   8.646667
# 40          76.11875             89.0         0.0000  12.448000
#
#      percentage expenditure  Hepatitis B     Measles       BMI  \
# 123               85.444275    42.909091  51653.9375  19.75000
# 40              1162.856329    96.222222     23.6875  52.35625
#
#      under-five deaths    Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 123           852.0625  41.3125           3.710667     39.3125   4.83125
# 40              0.0000  95.5000           7.370667     95.3750   0.10000
#
#              GDP    Population  thinness  1-19 years  \
# 123  1360.139877  7.087700e+07              10.41875
# 40   9056.784719  1.159772e+06               1.74375
#
#      Income composition of resources  Schooling
# 123                         0.367375     9.0000
# 40                          0.789063    13.8875

# %% [markdown]
# # Creating pipelines

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
pipeline = Pipeline([
    ('imputer' , SimpleImputer(strategy='mean')),
    ('std_scaler' , StandardScaler()),
])

# %%
final_training_data = pipeline.fit_transform(train_data)

# %%
final_training_data
# Out:
# array([[-1.9293391 ,  0.83339963,  4.06948817, ...,  1.2627092 ,
#         -1.50316544, -0.83820586],
#        [ 0.84184764, -0.85703575, -0.26127278, ..., -0.77126142,
#          0.96636889,  0.70074846],
#        [ 0.15010012,  0.38032055, -0.22034504, ..., -0.57636366,
#          0.54178614,  0.92706527],
#        ...,
#        [ 0.61732696, -1.15577649, -0.26127278, ..., -0.61006779,
#         -0.98561371,  0.22646714],
#        [-0.38567198, -0.42846534, -0.26127278, ..., -1.14347219,
#         -1.52439458,  0.00999019],
#        [-0.11638705, -0.03500193,  0.96100125, ..., -0.37853511,
#          0.10183056, -0.01559345]])

# %%
train_data_labels
# Out:
#      Life expectancy
# 123          51.35625
# 40           76.11875
# 180          69.93750
# 144          73.47500
# 117               NaN
# ..                ...
# 56           74.94375
# 74           73.82500
# 170          74.11250
# 88           65.15000
# 77           67.55625
#
# [154 rows x 1 columns]

# %%
train_data_labels = pipeline.fit_transform(train_data_labels)

# %%
train_data_labels = train_data_labels.ravel()
train_data_labels
# Out:
# array([-1.9293391 ,  0.84184764,  0.15010012,  0.54598394,  0.        ,
#         1.35243985, -0.04434458, -0.23669096,  0.68866998, -1.70132121,
#        -1.0690262 ,  0.59984093, -1.40895471, -1.48659271,  0.        ,
#         0.6991616 ,  0.88311468,  1.24612476, -1.93283631,  1.23982979,
#        -1.48029773, -0.45841388,  0.59494484, -0.38427309, -1.40825527,
#         1.52100522,  0.94396608, -0.355596  ,  0.4354722 ,  0.49142751,
#        -1.24388655,  1.54968232, -0.88507312,  1.36502979, -2.03775251,
#        -0.09960045,  0.        ,  0.        , -1.23899046,  0.56207109,
#        -0.97669994,  0.        ,  0.66069233,  1.35593706, -0.64866193,
#        -1.70971451,  1.55807561, -1.23409437,  0.58864986,  0.4760398 ,
#         0.        , -2.21750895,  0.64460517,  0.5452845 , -1.02216363,
#         0.54318617,  1.42168455, -2.24758493, -0.49198707,  0.55997277,
#        -0.44512449,  0.41938505,  0.63691132, -0.65495691, -1.24178822,
# ...

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
import joblib
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor 
from sklearn.svm import SVR

# %%
def run_model(feat , labels , name):
    
        # Building linear regression model
        if name == 'lr':
            lm = LinearRegression()
            lm.fit(feat,labels)
            pred_lm = lm.predict(feat)
            rmse_lm = np.sqrt(metrics.mean_squared_error(labels,pred_lm))
            print("rmse for lr : {}".format(rmse_lm))
            print('\n')
            print("r2 score :",metrics.r2_score(labels,pred_lm))
            print('\n')
        # Evaluating lm model
            lm_scores = cross_val_score(estimator = lm , X = feat , y = labels , scoring = 'neg_mean_squared_error' , cv=10)
            lm_rmse_scores = np.sqrt(-lm_scores)
            print('scores :' ,list(lm_scores))
            print('\n')
            print('Mean :' , lm_scores.mean())
            print('\n')
            print('std :' , lm_scores.std())
        
        #-------------------------------------------------------------------------------------------
        
        # Building Decision tree regressor
        
        if name == 'dtr':
            
            dtree = DecisionTreeRegressor()
            dtree.fit(feat,labels)
            pred_tree = dtree.predict(feat)
            rmse_tree = np.sqrt(metrics.mean_squared_error(labels,pred_tree))
            print("rmse for dtr : {}".format(rmse_tree))
            print('\n')
        # Evaluating tree model
            tree_scores = cross_val_score(estimator = dtree , X = feat , y = labels , scoring = 'neg_mean_squared_error' , cv=10)
            tree_rmse_scores = np.sqrt(-tree_scores)
            print('scores :' ,tree_scores)
            print('\n')
            print('Mean :' , tree_scores.mean())
            print('\n')
            print('std :' , tree_scores.std())

        #-------------------------------------------------------------------------------------------
        
        # Building random forest regressor
        if name == 'rfr':
            forest = RandomForestRegressor()
            forest.fit(feat,labels)
            pred_forest = forest.predict(feat)
            rmse_forest = np.sqrt(metrics.mean_squared_error(labels,pred_forest))
            print("rmse for dtr : {}".format(rmse_forest))
            print('\n')
        
        # Evaluating forest model
            forest_scores = cross_val_score(estimator = forest , X = feat , y = labels , scoring = 'neg_mean_squared_error' , cv=10)
            forest_rmse_scores = np.sqrt(-forest_scores)
            print('scores :' ,list(forest_scores))
            print('\n')
            print('Mean :' , forest_scores.mean())
            print('\n')
            print('std :' , forest_scores.std())

        #-------------------------------------------------------------------------------------------
        
        # Building support vector regressor model
        if name == 'svr':
            svr = SVR()
            svr.fit(feat,labels)
            pred_svr = svr.predict(feat)
            rmse_svr = np.sqrt(metrics.mean_squared_error(labels,pred_svr))
            print("rmse for svr : {}".format(rmse_svr))
            print('\n')
            
        # Evaluating svr model
            svr_scores = cross_val_score(estimator = svr , X = feat , y = labels , scoring = 'neg_mean_squared_error' , cv=10)
            svr_rmse_scores = np.sqrt(-svr_scores)
            print('scores :' ,list(svr_scores))
            print('\n')
            print('Mean :' , svr_scores.mean())
            print('\n')
            print('std :' , svr_scores.std())

# %%
decision_tree_reg  = run_model(final_training_data , train_data_labels , 'dtr')
# Out:
# rmse for dtr : 8.856515911953196e-17
#
#
# scores : [-0.00194486 -0.00312953 -0.00621347 -0.00911845 -0.00703336 -0.00635204
#  -0.01159965 -0.00309799 -0.00219029 -0.00273802]
#
#
# Mean : -0.005341765689871018
#
#
# std : 0.0031023418972393113

# %%
linear_regression = run_model(final_training_data , train_data_labels , 'lr')
# Out:
# rmse for lr : 1.2540795896044223e-15
#
#
# r2 score : 1.0
#
#
# scores : [-3.1632307670018576e-30, -7.3204597186158835e-31, -1.0794593149004847e-30, -1.5087027555444366e-30, -2.121072098689007e-30, -1.4796277786079004e-31, -1.5907025782671935e-30, -9.606737032046209e-31, -2.0782100152066938e-30, -5.254919743348605e-31]
#
#
# Mean : -1.3907551956871533e-30
#
#
# std : 8.49146844452149e-31

# %%
random_forest_regressor = run_model(final_training_data , train_data_labels , 'rfr')
# Out:
# rmse for dtr : 0.01556421152603998
#
#
# scores : [-0.0027272453498176424, -0.0030592008792343127, -0.0011801548829643873, -0.0035922105020065372, -0.010480980290691043, -0.0018395019580824486, -0.001050566975223624, -0.0010673671244132497, -0.0008744723827426649, -0.0012069146018684118]
#
#
# Mean : -0.002707861494704432
#
#
# std : 0.002747129483130096

# %%
support_vector_regressor = run_model(final_training_data , train_data_labels , 'svr')
# Out:
# rmse for svr : 0.10674519312107537
#
#
# scores : [-0.14894974120515253, -0.07520162437220376, -0.048461695052097783, -0.04535506564738514, -0.05502743396994258, -0.026526589788222095, -0.023686566201459813, -0.1251975945022362, -0.04418764784151079, -0.021467043784591182]
#
#
# Mean : -0.06140610023648019
#
#
# std : 0.0411343990490453
